# %% [markdown]
# ##### a. List

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #### Add elements to a list

# %%
lst = [45,66,98,27,78,44]
lst
# Out:
# [45, 66, 98, 27, 78, 44]

# %%
# Add one element to the end of list
lst.append(99)

# %%
lst
# Out:
# [45, 66, 98, 27, 78, 44, 99]

# %%
lst.append(91)
lst
# Out:
# [45, 66, 98, 27, 78, 44, 99, 91]

# %%
lst
# Out:
# [45, 66, 98, 27, 78, 44, 99, 91]

# %%
# Add multiple elements to the end of the list
lst.extend([4,5,6])
lst
# Out:
# [45, 66, 98, 27, 78, 44, 99, 91, 4, 5, 6]

# %%
lst.append([4,5,6])
lst
# Out:
# [45, 66, 98, 27, 78, 44, 99, 91, 4, 5, 6, [4, 5, 6]]

# %%
lst.insert(6,100)
lst
# Out:
# [45, 66, 98, 27, 78, 44, 100, 99, 91, 4, 5, 6, [4, 5, 6]]

# %%
shop_lst = ['Apples','Orange','Rice','Butter','Soap','Shampoo']
shop_lst
# Out:
# ['Apples', 'Orange', 'Rice', 'Butter', 'Soap', 'Shampoo']

# %%
shop_lst.extend(['Pen','Pencil'])
shop_lst
# Out:
# ['Apples', 'Orange', 'Rice', 'Butter', 'Soap', 'Shampoo', 'Pen', 'Pencil']

# %%
shop_lst.insert(3,'Bread')
shop_lst
# Out:
# ['Apples',
#  'Orange',
#  'Rice',
#  'Bread',
#  'Butter',
#  'Soap',
#  'Shampoo',
#  'Pen',
#  'Pencil']

# %% [markdown]
# #### Remove elements from a list

# %%
lst
# Out:
# [45, 66, 98, 27, 78, 44, 100, 99, 91, 4, 5, 6, [4, 5, 6]]

# %%
lst.pop()
# Out:
# [4, 5, 6]

# %%
lst
# Out:
# [45, 66, 98, 27, 78, 44, 100, 99, 91, 4, 5, 6]

# %%
lst.pop()
lst
# Out:
# [45, 66, 98, 27, 78, 44, 100, 99, 91, 4, 5]

# %%
lst.pop(3)
# Out:
# 27

# %%
lst
# Out:
# [45, 66, 98, 78, 44, 100, 99, 91, 4, 5]

# %%
lst.remove(100)
lst
# Out:
# [45, 66, 98, 78, 44, 99, 91, 4, 5]

# %%
shop_lst
# Out:
# ['Apples',
#  'Orange',
#  'Rice',
#  'Bread',
#  'Butter',
#  'Soap',
#  'Shampoo',
#  'Pen',
#  'Pencil']

# %%
# shop_lst.pop(2)
shop_lst.remove('Rice')
shop_lst
# Out:
# ['Apples', 'Orange', 'Bread', 'Butter', 'Soap', 'Shampoo', 'Pen', 'Pencil']

# %%
lst.clear()
lst
# Out:
# []

# %% [markdown]
# #### order the elements

# %%
lst = [45,66,98,27,78,44]
lst
# Out:
# [45, 66, 98, 27, 78, 44]

# %%
#Ascending Order
lst.sort()
lst
# Out:
# [27, 44, 45, 66, 78, 98]

# %%
lst.sort(reverse=True)
lst
# Out:
# [98, 78, 66, 45, 44, 27]

# %%
l1 = [45,32,78]

# %%
l1.reverse()
l1
# Out:
# [78, 32, 45]

# %%
shop_lst.sort()
shop_lst
# Out:
# ['Apples', 'Bread', 'Butter', 'Orange', 'Pen', 'Pencil', 'Shampoo', 'Soap']

# %%
# Not possible
l2 = [23,45,[1,2,3]]
#l2.sort()

# %%
shop_lst
# Out:
# ['Apples', 'Bread', 'Butter', 'Orange', 'Pen', 'Pencil', 'Shampoo', 'Soap']

# %%
shop_lst.index('Pencil')
# Out:
# 5

# %%
name_lst = ['Tom','Tim','Tom','Jim','Kim','Tom']
name_lst.count('Tom')
# Out:
# 3

# %% [markdown]
# ### Assign Vs Copy

# %% [markdown]
# ##### a. assign

# %%
l1 = [1,2,3]
l2 = l1

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3, 100]

# %% [markdown]
# ##### b. copy()

# %%
l1 = [1,2,3]
l2 = l1.copy()

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)

# %%
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3]

# %% [markdown]
# #### Tuple

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
names = ('Tom','Tim','Tom','Jim','Kim','Tom')
names.count('Tom')
# Out:
# 3

# %%
names.index('Tom')
# Out:
# 0

# %% [markdown]
# #### String

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
s1 = 'i love python'
s1
# Out:
# 'i love python'

# %%
s1.capitalize()
# Out:
# 'I love python'

# %%
s1.title()
# Out:
# 'I Love Python'

# %%
s1.upper()
# Out:
# 'I LOVE PYTHON'

# %%
s2 = 'I Love Python'

# %%
s2.lower()
# Out:
# 'i love python'

# %%
s2.swapcase()
# Out:
# 'i lOVE pYTHON'

# %%
s3 = 'python'

# %%
s3.startswith('py'), s3.startswith('on')
# Out:
# (True, False)

# %%
s3.endswith('py'), s3.endswith('on')
# Out:
# (False, True)

# %%
# Replace a part of the string
s4 = 'Anarkali'
s4.replace('Anar', 'Champa')
# Out:
# 'Champakali'

# %%
# Remove a part of the string 
s5 = 'Abc%xyz'
s5.replace('%','')
# Out:
# 'Abcxyz'

# %% [markdown]
# ### split()

# %%
sent1 = "This is an example for using the split function in python"

# %%
word_lst = sent1.split()
word_lst
# Out:
# ['This',
#  'is',
#  'an',
#  'example',
#  'for',
#  'using',
#  'the',
#  'split',
#  'function',
#  'in',
#  'python']

# %%
fruits ="Apple,Orange,Grapes,Papaya"

# %%
fruit_list = fruits.split(',')
fruit_list
# Out:
# ['Apple', 'Orange', 'Grapes', 'Papaya']

# %%
fruits ="Apple|Orange,Grapes|Papaya"

# %%
fruits.split('|')
# Out:
# ['Apple', 'Orange,Grapes', 'Papaya']

# %%
' '.join(word_lst)
# Out:
# 'This is an example for using the split function in python'

# %%
','.join(word_lst)
# Out:
# 'This,is,an,example,for,using,the,split,function,in,python'

# %%
lst = [1,3,2]
lst.sort()

# %%
lst
# Out:
# [1, 2, 3]

# %%
s1.upper()
# Out:
# 'I LOVE PYTHON'

# %%
s1
# Out:
# 'i love python'

# %%
s2 = '   python   '

# %%
s2.rstrip(), s2.lstrip() , s2.strip()
# Out:
# ('   python', 'python   ', 'python')

# %%
lst.rstrip()

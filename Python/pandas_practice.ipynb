# %%
import pandas as pd

# %%
edata = [
    [100,'Thomas','Mgr',3200],
    [200,'Mary','Pgmr',4700],
    [300,'Kate','HR',2800],
    [400,'Jon','Mgr', 3000],
    [500,'Jim','Pgmr',7600],
    [600,'Harry','HR',4800]
]

# %%
e1 = pd.DataFrame(edata)
#e1

# %%
type(e1)
# Out:
# pandas.core.frame.DataFrame

# %%
e2 = pd.DataFrame(edata, columns=['eid','ename','job','sal'])
#e2

# %%
edf = pd.DataFrame(edata, 
                   columns=['eid','ename','job','sal'], 
                   index=['e1','e2','e3','e4','e5','e6']
                  )
edf
# Out:
#     eid   ename   job   sal
# e1  100  Thomas   Mgr  3200
# e2  200    Mary  Pgmr  4700
# e3  300    Kate    HR  2800
# e4  400     Jon   Mgr  3000
# e5  500     Jim  Pgmr  7600
# e6  600   Harry    HR  4800

# %% [markdown]
# #### Accessing Data

# %% [markdown]
# #### Single Row

# %%
edf.loc['e3',:]
### Exception
edf.loc['e3']
# Out:
# eid       300
# ename    Kate
# job        HR
# sal      2800
# Name: e3, dtype: object

# %%
edf.iloc[2,:]
### Exception
edf.iloc[2]
# Out:
# eid       300
# ename    Kate
# job        HR
# sal      2800
# Name: e3, dtype: object

# %% [markdown]
# #### Range of Rows

# %%
edf.loc['e3':'e5', :]
### Exception
edf.loc['e3':'e5']
# Out:
#     eid ename   job   sal
# e3  300  Kate    HR  2800
# e4  400   Jon   Mgr  3000
# e5  500   Jim  Pgmr  7600

# %%
edf.iloc[2:5, :]
### Exception
#edf.iloc[2:5]
# Out:
#     eid ename   job   sal
# e3  300  Kate    HR  2800
# e4  400   Jon   Mgr  3000
# e5  500   Jim  Pgmr  7600

# %% [markdown]
# #### Random Rows

# %%
edf.loc[['e2','e4'], :]
### Exception
edf.loc[['e2','e4']]
# Out:
#     eid ename   job   sal
# e2  200  Mary  Pgmr  4700
# e4  400   Jon   Mgr  3000

# %%
edf.iloc[[1,3],:]
### Exception
edf.iloc[[1,3]]
# Out:
#     eid ename   job   sal
# e2  200  Mary  Pgmr  4700
# e4  400   Jon   Mgr  3000
